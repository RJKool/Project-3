# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json

# %%
# Load in the dataframe from project part 1 as basics:
ratings_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/Final_RATINGS.csv.gz')
ratings_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       265
# 2  tt0000005            6.2      2634
# 3  tt0000006            5.1       182
# 4  tt0000007            5.4       825

# %%
basics_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/Final_BASICS.csv.gz')
basics_df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
TMDB_2000s_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/final_tmdb_data_2000.csv.gz')
TMDB_2000s_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1244  tt6174238    0.0                               NaN
# 1245  tt7029820    0.0                               NaN
# 1246  tt7197642    0.0                               NaN
# 1247  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1248  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...

# %%
TMDB_2001s_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/final_tmdb_data_2001.csv.gz')
TMDB_2001s_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# ...         ...    ...                               ...
# 1340  tt7797790    0.0                               NaN
# 1341  tt8665056    0.0                               NaN
# 1342  tt8795764    0.0                               NaN
# 1343  tt9071078    0.0                               NaN
# 1344  tt9212730    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  22000000.0
# ...

# %%
#merging TMDB calls 
tmdb_merged2k = pd.concat([TMDB_2000s_df,TMDB_2001s_df],ignore_index=True)
tmdb_merged2k.head(2)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
#
#         id original_language   original_title  ...  \
# 0      NaN               NaN              NaN  ...
# 1  62127.0                en  The Fantasticks  ...
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                          tagline            title video  \
# 0                                            NaN              NaN   NaN
# ...

# %%
new_basics_df = basics_df[[ 'tconst', 'primaryTitle','startYear','runtimeMinutes','genres' ]]
new_basics_df.head(2)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama

# %%
new_ratings_df = ratings_df
new_ratings_df.head(2)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       265

# %%
new_tmdb_df = tmdb_merged2k[[ 'imdb_id', 'Movie_Revenue','Movie_Budget', 'MPAA_Rating']]
new_tmdb_df.head(2)
# Out:
#      imdb_id  Movie_Revenue  Movie_Budget MPAA_Rating
# 0          0            NaN           NaN         NaN
# 1  tt0113026            0.0    10000000.0         NaN

# %%
#################STRAIGHT FROM LP########################

# %% [markdown]
# # 1. Getting a List of Unique Genres

# %%
##1> create a col with a list of genres
basics_df['genres_split'] = basics_df['genres'].str.split(',')
basics_df.head(2)
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
#
#    runtimeMinutes                  genres                genres_split
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]

# %%
##2> We will then use .explode() to separate the list of genres into
##new rows: one row for each genre a movie belonged to.
exploded_genres = basics_df.explode('genres_split')
exploded_genres.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 0                             Kate & Leopold        0     2001.0      NaN
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
#
#    runtimeMinutes                  genres genres_split
# ...

# %%
#Finally, use .unique() to get the unique genres from the `genres_split` column.
# * We can run this through `sorted` function to get the genres sorted alphabetically.
# * Save this list of unique genres. We will use it again in a later step.
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %% [markdown]
# # 2. Create a new `title_genres` table
#
# * Next, create a new `title_genres` from the exploded df.
#     * We only want the tconst and genres_split columns.

# %%
#Save just tconst and genres_split as new df
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0068865        Drama

# %% [markdown]
# # 3. Create a genre mapper dictionary to replace string genres with integers
# * Next, we want to use the approach for creating a numeric id that we introduced in the advanced transformations with Pandas lesson.
#     * Reminder: we will use the `dict` and `zip` functions to make a dictionary with the genre strings as the keys and the integers genre_ids as the values.

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %% [markdown]
# # 4. Replace the string genres in `title_genres` with the new integer ids.
#     * Create a new `genre_id` column using the `genre_map` dictionary with either .map or .replace.
#     * Next, drop the "genres_split" column.
#     * Your `title_genres` table is now ready for your MySQL database!

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns='genres_split')

# %% [markdown]
# # 5. Convert the genre map dictionary into a dataframe.
# * There are several ways to do this. Here is one suggested approach:

# %%
# Manually make dataframe with name cols from the .keys and .values
genre_lookup = pd.DataFrame({'Genre_Name':genre_map.keys(),
                             'Genre_ID':genre_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# Now your `genres` table is all set for your MySQL database!
#
# ---

# %% [markdown]
# # II) Saving the MySQL tables with tconst as the primary key.
#
# * You will need to make sure to set the Primary Key for each table that you create with pandas + sqlalchemy that is not a joiner table. (e.g., title_genres is a joiner table, and it does not have a primary key).
#     * If we had an integer id columns, this would be as simple as:
#
# `## Set the dataframe index and use index=True
# df.set_index('int_index').to_sql('table_name',engine,index=True)`
#
#     * Because we have a string column ("tconst") as the primary key for several tables, we will need to go through some extra steps.
#     * If we do not perform these steps (detailed below) approach, we will run into the following error:
#
# ## Using `tconst` as the primary key.
# * To use a string column as our primary key, we will need to provide the SQL datatype schema of our columns when we create the table.
#     * We will then use our engine to run the command to alter our table and add tconst as the primary key.
# ### 1. Creating a dataype schema for to_sql:
# * Check the dtypes of your dataframe: (df.dtypes).
#     * Create a dictionary with each column name as a key and the corresponding SQL datatype as the value.
# * Find the corresponding SQLalchemy datatype to use in the table below.
#
# ![image.png](attachment:image.png)
#
# * Note on String Columns:
#     * For columns with "object" dtype, you should use:
#         * the String type if the column will become your primary key.
#         * Otherwise, use the Text data type.
#         * Both String/Text will need the maximum string length to use for that column.
# * You can find the maximum string length (max_str_len) for any text column using the following code:

# %%
## get max string length
#max_str_len = df['column'].fillna('').map(len).max()

# %%
type(basics_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Then Use 1 larger than the max_str_len for your String/Text object `Text(max_str_len +1 )`.

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics_df['tconst'].fillna('').map(len).max()
title_len = basics_df['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %% [markdown]
# ## 2. Run `df.to_sql` with the dtype argument.
# * Use this dictionary as the `dtype` argument in `df.to_sql` (make sure `index=False`)

# %%
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %%
from urllib.parse import quote_plus   # This import is needed if you have a
                                      # special character in your password.

username = "root"
password = quote_plus("ViperRT/10") # (whatever password you chose during mysql installation).
                                    # Using the quote function to make the password compatible
                                    # when it has special characters included.
db_name = "Pro3P"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
## Check if database exists, if not, create it
if database_exists(connection) == False: 
    create_database(connection)
else: 
    print('The database already exists.')
# Out:
# The database already exists.

# %%
#Connection engine between Python and MySQL
engine = create_engine(connection)

# %%
#type(df_schema)

# %%
#basics_df = basics_df.loc[titlebasics['tconst']!='0']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 basics_df = basics_df.loc[titlebasics['tconst']!='0']
#
# NameError: name 'titlebasics' is not defined

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics_df['tconst'].fillna('').map(len).max()
title_len = basics_df['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Save to sql with dtype and index=False
basics_df.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#
# ...

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')
