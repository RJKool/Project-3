# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, time, json, math
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook   # to make a progress bar from tqdm_notebook
FOLDER = "/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['.ipynb_checkpoints',
#  'Data',
#  'Final_AKAS.csv.gz',
#  'Final_BASICS.csv.gz',
#  'Final_RATINGS.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'Movies_in_2000.csv.gz',
#  'Movies_in_2001.csv.gz',
#  'Part_2.ipynb',
#  'Project 3 - Part 1.ipynb',
#  'Project 3 - Part 2.ipynb',
#  'title-akas-us-only.csv',
#  'title.akas.tsv.gz',
#  'title.basics.tsv.gz',
#  'title.ratings.tsv.gz']

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
def get_movie_with_rating(movie_id):
    
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    
    # save the .info .releases dictionaries
    info = movie.info()
    releases = movie.releases()
    
    # Loop through countries in releases
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
            ## save a "certification" key in the info dict with the certification
            info['MPAA_Rating'] = c['certification']

    info['Movie_Budget'] = info['budget']
    info['Movie_Revenue'] = info['revenue']

    return info

# %%
# Load in the dataframe from project part 1 as basics:
basics_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/Final_BASICS.csv.gz')

# %%
basics_df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0068865     movie                                Lives of Performers
# 3      tt0069049     movie                         The Other Side of the Wind
# 4      tt0088751     movie                                  The Naked Monster
# ...          ...       ...                                                ...
# 81898  tt9914942     movie                             Life Without Sara Amat
# 81899  tt9915872     movie                               The Last White Witch
# 81900  tt9916170     movie                                      The Rehearsal
# 81901  tt9916190     movie                                          Safeguard
# 81902  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                            Lives of Performers        0     2016.0      NaN
# 3                     The Other Side of the Wind        0     2018.0      NaN
# 4                              The Naked Monster        0     2005.0      NaN
# ...                                          ...      ...        ...      ...
# 81898                 La vida sense la Sara Amat        0     2019.0      NaN
# 81899              Boku no kanojo wa mahoutsukai        0     2019.0      NaN
# 81900                                   O Ensaio        0     2019.0      NaN
# 81901                                  Safeguard        0     2020.0      NaN
# 81902                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                  90                      Drama
# 3                 122                      Drama
# 4                 100       Comedy,Horror,Sci-Fi
# ...               ...                        ...
# 81898              74                      Drama
# 81899              97       Comedy,Drama,Fantasy
# 81900              51                      Drama
# 81901              95  Action,Adventure,Thriller
# 81902              92              Drama,History
#
# [81903 rows x 9 columns]

# %% [markdown]
# # Movies that started in the year 2000.

# %%
movies_in_2000_df = basics_df[basics_df['startYear'] == 2000]
movies_in_2000_df
# Out:
#           tconst titleType                                       primaryTitle  \
# 9      tt0113026     movie                                    The Fantasticks
# 10     tt0113092     movie                                      For the Cause
# 12     tt0115937     movie                                        Consequence
# 13     tt0116391     movie                                               Gang
# 14     tt0116628     movie                                   The Incorporated
# ...          ...       ...                                                ...
# 77254  tt8327752     movie  Unknown the Great: The Life & Times of Buddy S...
# 77998  tt8553964     movie                                      Cotton Fleece
# 79088  tt8907070     movie                             Lost in the Wilderness
# 79230  tt8954964     movie                                          Good Luck
# 80645  tt9412476     movie                                Contratiempo Mortal
#
#                                            originalTitle  isAdult  startYear  \
# 9                                        The Fantasticks        0     2000.0
# 10                                         For the Cause        0     2000.0
# 12                                           Consequence        0     2000.0
# 13                                                  Gang        0     2000.0
# 14                                      The Incorporated        0     2000.0
# ...                                                  ...      ...        ...
# 77254  Unknown the Great: The Life & Times of Buddy S...        0     2000.0
# 77998                                      Cotton Fleece        0     2000.0
# 79088                             Lost in the Wilderness        0     2000.0
# 79230                                          Good Luck        0     2000.0
# 80645                                Contratiempo Mortal        0     2000.0
#
#        endYear  runtimeMinutes                  genres
# 9          NaN              86         Musical,Romance
# 10         NaN             100  Action,Adventure,Drama
# 12         NaN              91                   Drama
# 13         NaN             167      Action,Crime,Drama
# 14         NaN              86         Action,Thriller
# ...        ...             ...                     ...
# 77254      NaN              77            Comedy,Music
# 77998      NaN              90                   Drama
# 79088      NaN              77                  Comedy
# 79230      NaN             142                   Drama
# 80645      NaN              90                  Action
#
# [1457 rows x 9 columns]

# %%
#Saving "movies_in_2000_df" dataframe to .csv that is compressed.
movies_in_2000_df.to_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/Movies_in_2000.csv.gz', compression='gzip', index=False)

# %% [markdown]
# # Movies that started in the year 2001.

# %%
movies_in_2001_df = basics_df[basics_df['startYear'] == 2001]
movies_in_2001_df
# Out:
#           tconst titleType           primaryTitle          originalTitle  \
# 0      tt0035423     movie         Kate & Leopold         Kate & Leopold
# 11     tt0114447     movie       The Silent Force       The Silent Force
# 15     tt0116916     movie     The Lord Protector     The Lord Protector
# 19     tt0118589     movie                Glitter                Glitter
# 20     tt0118652     movie  The Attic Expeditions  The Attic Expeditions
# ...          ...       ...                    ...                    ...
# 79662  tt9071078     movie            Dragon Hero       Mo ren kuang dao
# 80118  tt9212730     movie          Yakuza Zombie           Zonbi gokudo
# 80151  tt9228234     movie        The Narc Enigma        The Narc Enigma
# 80938  tt9555974     movie         Haunted School           Gui xue xiao
# 80992  tt9578462     movie             Crying Sky     Ku qi de tian kong
#
#        isAdult  startYear  endYear  runtimeMinutes                    genres
# 0            0     2001.0      NaN             118    Comedy,Fantasy,Romance
# 11           0     2001.0      NaN              90                    Action
# 15           0     2001.0      NaN             101  Action,Adventure,Fantasy
# 19           0     2001.0      NaN             104       Drama,Music,Romance
# 20           0     2001.0      NaN             100     Comedy,Horror,Mystery
# ...        ...        ...      ...             ...                       ...
# 79662        0     2001.0      NaN             100     Action,Drama,Thriller
# 80118        0     2001.0      NaN              87           Horror,Thriller
# 80151        0     2001.0      NaN              93                    Action
# 80938        0     2001.0      NaN              85                    Horror
# 80992        0     2001.0      NaN              85                     Drama
#
# [1577 rows x 9 columns]

# %%
#Saving "movies_in_2001_df" dataframe to .csv that is compressed.
movies_in_2001_df.to_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/Movies_in_2001.csv.gz', compression='gzip', index=False)

# %%
list_2000 = list(movies_in_2000_df['tconst'])
list_2001 = list(movies_in_2001_df['tconst'])

# %%
# CREDENTIALS AND ACCESSING THE TMDB API
with open('/Users/Rashad/.secret/tmdb_api_key.json','r') as rc:
    login = json.load(rc)

# %%
# quick view of login dictionary keys
login.keys()
# Out:
# dict_keys(['api_key', 'api_read_token'])

# %%
# Instantiate TMDB API VARIABLE by loading the TMDB API KEY
tmdb.API_KEY = login['api_key']

# %%
# Specifying JSON_FILE filename (can include a folder)
# include the search terms in the filename

#JSON_FILE = "Data/results_in_progress_movie_year.json"
JSON_FILE = "/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/Data/results_in_progress_movie_year.json"

# %%
YEARS_TO_GET = [2000,2001]

# %%
errors = [ ]

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # If it does not exist: create it
    if file_exists == False:
        # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)
    
    #Saving new year as the current df
    df = basics_df.loc[ basics_df['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()
    
    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    
    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
    
    #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 40 ms sleep to prevent overwhelming server
            time.sleep(0.04)
            
        except Exception as e:
            errors.append([movie_id, e])
    
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/1457 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/1577 [00:00<?, ?it/s]

# %%
# total errors found
print(f"- Total errors: {len(errors)}")
# Out:
# - Total errors: 442

# %%
# check created csv file.  converting it into datafram to view.
the2000s_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/final_tmdb_data_2000.csv.gz')
the2000s_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1244  tt6174238    0.0                               NaN
# 1245  tt7029820    0.0                               NaN
# 1246  tt7197642    0.0                               NaN
# 1247  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1248  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 1244                   NaN         0.0
# 1245                   NaN      7000.0
# 1246                   NaN         0.0
# 1247                   NaN  10000000.0
# 1248                   NaN         0.0
#
#                                                  genres homepage        id  \
# 0                                                   NaN      NaN       NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2              [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  442869.0
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     843.0
# ...                                                 ...      ...       ...
# 1244                      [{'id': 80, 'name': 'Crime'}]      NaN  223878.0
# 1245                                                 []      NaN  604889.0
# 1246                     [{'id': 35, 'name': 'Comedy'}]      NaN  872676.0
# 1247                     [{'id': 27, 'name': 'Horror'}]      NaN   97186.0
# 1248  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN  610992.0
#
#      original_language           original_title  ...  \
# 0                  NaN                      NaN  ...
# 1                   en          The Fantasticks  ...
# 2                   en            For the Cause  ...
# 3                   hi                     Gang  ...
# 4                   cn                     花樣年華  ...
# ...                ...                      ...  ...
# 1244                cn                       冷战  ...
# 1245                en     Scream For Christmas  ...
# 1246                en  Goodbye, Merry-Go-Round  ...
# 1247                fr               I, Vampire  ...
# 1248                fa                مومیایی ۳  ...
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 1244  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1245                                                 []  Released
# 1246                                                 []  Released
# 1247  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1248  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 1244                                                NaN
# 1245                                                NaN
# 1246                                                NaN
# 1247                                                NaN
# 1248                                                NaN
#
#                         title video vote_average  vote_count  MPAA_Rating  \
# 0                         NaN   NaN          NaN         NaN          NaN
# 1             The Fantasticks   0.0         5.50        22.0          NaN
# 2               For the Cause   0.0         5.45        10.0          NaN
# 3                        Gang   0.0         4.00         1.0          NaN
# 4        In the Mood for Love   0.0         8.11      2281.0           PG
# ...                       ...   ...          ...         ...          ...
# 1244                 Cold War   0.0         2.00         2.0          NaN
# 1245     Scream For Christmas   0.0         0.00         0.0          NaN
# 1246  Goodbye, Merry-Go-Round   0.0         0.00         0.0          NaN
# 1247               I, Vampire   0.0         6.40         4.0           NR
# 1248              The Mummy 3   0.0         7.00         1.0          NaN
#
#      Movie_Budget Movie_Revenue
# 0             NaN           NaN
# 1      10000000.0           0.0
# 2             0.0           0.0
# 3             0.0           0.0
# 4        150000.0    14204632.0
# ...           ...           ...
# 1244          0.0           0.0
# 1245       7000.0           0.0
# 1246          0.0           0.0
# 1247   10000000.0           0.0
# 1248          0.0           0.0
#
# [1249 rows x 28 columns]

# %%
# check created csv file.  converting it into datafram to view.
the2001s_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/final_tmdb_data_2001.csv.gz')
the2001s_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# ...         ...    ...                               ...
# 1340  tt7797790    0.0                               NaN
# 1341  tt8665056    0.0                               NaN
# 1342  tt8795764    0.0                               NaN
# 1343  tt9071078    0.0                               NaN
# 1344  tt9212730    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  22000000.0
# ...                    ...         ...
# 1340                   NaN         0.0
# 1341                   NaN         0.0
# 1342                   NaN         0.0
# 1343                   NaN         0.0
# 1344                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 3     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# ...                                                 ...
# 1340                     [{'id': 27, 'name': 'Horror'}]
# 1341                    [{'id': 37, 'name': 'Western'}]
# 1342                     [{'id': 27, 'name': 'Horror'}]
# 1343                     [{'id': 28, 'name': 'Action'}]
# 1344  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   11232.0
# 2                                                   NaN  151007.0
# 3                                                   NaN   73549.0
# 4                                                   NaN   10696.0
# ...                                                 ...       ...
# 1340                                                NaN  956219.0
# 1341  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1342  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1343                                                NaN  201706.0
# 1344                                                NaN  382630.0
#
#      original_language                       original_title  ...  \
# 0                  NaN                                  NaN  ...
# 1                   en                       Kate & Leopold  ...
# 2                   en                     The Silent Force  ...
# 3                   en                        The Dark Mist  ...
# 4                   en                              Glitter  ...
# ...                ...                                  ...  ...
# 1340                en  Edmund Kemper Part 3: La mort sévit  ...
# 1341                en                 Guns Along The Bravo  ...
# 1342                en                            New Breed  ...
# 1343                cn                                 致命密函  ...
# 1344                ja                           実録外伝 ゾンビ極道  ...
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 1340  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 1341                                                 []  Released
# 1342  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1343  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1344  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1     If they lived in the same century, they'd be p...
# 2     They left him for dead... They should have fin...
# 3                                                   NaN
# 4      In music she found her dream, her love, herself.
# ...                                                 ...
# 1340                                                NaN
# 1341  Evil came to the Southwest until three blazing...
# 1342                                                NaN
# 1343                                                NaN
# 1344                                                NaN
#
#                                     title video vote_average  vote_count  \
# 0                                     NaN   NaN          NaN         NaN
# 1                          Kate & Leopold   0.0        6.330      1215.0
# 2                        The Silent Force   0.0        5.000         3.0
# 3                           The Dark Mist   0.0        3.500         2.0
# 4                                 Glitter   0.0        4.438       129.0
# ...                                   ...   ...          ...         ...
# 1340  Edmund Kemper Part 3: La mort sévit   0.0        0.000         0.0
# 1341                 Guns Along The Bravo   0.0        0.000         0.0
# 1342                            New Breed   0.0        0.000         0.0
# 1343                       Chinese Heroes   0.0        3.000         2.0
# 1344                        Yakuza Zombie   0.0        0.000         0.0
#
#       MPAA_Rating Movie_Budget Movie_Revenue
# 0             NaN          NaN           NaN
# 1           PG-13   48000000.0    76019048.0
# 2             NaN          0.0           0.0
# 3              PG          0.0           0.0
# 4           PG-13   22000000.0     5271666.0
# ...           ...          ...           ...
# 1340          NaN          0.0           0.0
# 1341          NaN          0.0           0.0
# 1342           NR          0.0           0.0
# 1343          NaN          0.0           0.0
# 1344          NaN          0.0           0.0
#
# [1345 rows x 28 columns]
