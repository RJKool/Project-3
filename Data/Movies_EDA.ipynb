# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading year 2000 movie data into dataframe
the2000s_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/final_tmdb_data_2000.csv.gz')
the2000s_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1244  tt6174238    0.0                               NaN
# 1245  tt7029820    0.0                               NaN
# 1246  tt7197642    0.0                               NaN
# 1247  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1248  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...

# %%
# Loading year 2001 movie data into dataframe
the2001s_df = pd.read_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/final_tmdb_data_2001.csv.gz')
the2001s_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# ...         ...    ...                               ...
# 1340  tt7797790    0.0                               NaN
# 1341  tt8665056    0.0                               NaN
# 1342  tt8795764    0.0                               NaN
# 1343  tt9071078    0.0                               NaN
# 1344  tt9212730    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  22000000.0
# ...

# %%
# Merging both movie years into a single dataframe.
mov_2000_2001 = pd.merge(the2000s_df, the2001s_df, how='outer')

# %%
mov_2000_2001.head(2)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
#
#         id original_language   original_title  ...  \
# 0      NaN               NaN              NaN  ...
# 1  62127.0                en  The Fantasticks  ...
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                          tagline            title video  \
# 0                                            NaN              NaN   NaN
# ...

# %%
bud_rev = mov_2000_2001[ (mov_2000_2001['Movie_Budget'] > 0) & (mov_2000_2001['Movie_Revenue'] > 0) ]
len(bud_rev)
# Out:
# 359

# %%
bud_rev['MPAA_Rating'].value_counts().plot(kind='bar')
plt.title("Number of Movie Ratings")
# Out:
# Text(0.5, 1.0, 'Number of Movie Ratings')

# %%
fig = sns.barplot(data=bud_rev, x='MPAA_Rating', y='Movie_Revenue');
fig.set(xlabel = "Movies", ylabel="Budget in Millions")
plt.title("Movie Revenue")
# Out:
# Text(0.5, 1.0, 'Movie Revenue')

# %%
fig = sns.barplot(data=bud_rev, x='MPAA_Rating', y='Movie_Budget');
fig.set(xlabel = "Movies", ylabel="Budget in Millions")
plt.title("Movie Budgets")
# Out:
# Text(0.5, 1.0, 'Movie Budgets')

# %%
#merged save

#Saving merged "mov_2000_2001" dataframe to .csv that is compressed.
mov_2000_2001.to_csv('/Users/Rashad/Documents/GitHub/Test Repo/Project 3/Project-3/Data/tmdb_results_combined.csv.gz', compression='gzip', index=False)
